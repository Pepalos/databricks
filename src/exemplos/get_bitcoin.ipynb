# %%
import requests 
import pandas as pd 
from datetime import datetime

response = requests.get("https://api.coibase.com/v2/prices/spot")

dados_bitcoin = response.json()
print(dados_bitcoin)
print(dados_bitcoin['data']['price']['usd'])
